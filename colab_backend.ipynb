# %% [markdown]
# # CourtSense AI - Free Online Backend
#
# This notebook allows you to run the CourtSense AI backend for free using Google Colab's cloud servers.
#
# **Instructions:**
# 1. In the menu, go to **Runtime > Change runtime type** and ensure Hardware accelerator is set to **T4 GPU** (or CPU if GPU is unavailable, though GPU is much faster for YOLOv8).
# 2. Click the "Play" button on each cell below (or go to **Runtime > Run all**).
# 3. Copy the URL printed at the very end.
# 4. Go to your frontend site (`https://udayraj1238.github.io/CourtSense-AI/`), click the Settings ⚙️ icon, and paste the URL.

# %%
# 1. Clone the repository and install requirements
# !git clone https://github.com/udayraj1238/CourtSense-AI.git
# %cd CourtSense-AI
# !pip install -r requirements.txt
# !npm install -g localtunnel
# We need this for OpenCV in colab
# !apt-get update
# !apt-get install -y libgl1-mesa-glx

# %%
import urllib.request

print("\n=======================================================")
print("COPY SUBMIT PASSWORD (if prompted):")
print(urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())
print("=======================================================\n")

# 2. Run the FastAPI server in the background 
get_ipython().system_raw('cd backend && uvicorn main:app --host 0.0.0.0 --port 8000 &')

# 3. Open Localtunnel endpoint (Copy the your url is: ... link!)
# !lt --port 8000
